# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Turkey-Car-Market-Analysis/blob/main/Turkey_Car_Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random

# %%
car=pd.read_csv("car.csv")

# %%
car.head(3)
# Out:
#   İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0  27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1  16/06/2020   Acura             CL                    -     2015.0
# 2  14/06/2020   Acura             CL                  2.2     1994.0
#
#    Yakıt Turu                Vites           CCM Beygir Gucu       Renk  \
# 0       Dizel       Otomatik Vites  1801-2000 cc  176-200 BG  Lacivert
# 1       Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG      Mavi
# 2  Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG   Turkuaz
#
#           Kasa Tipi      Kimden  Durum      Km   Fiyat
# 0  Hatchback 5 Kapı   Galeriden  2. El   26100  634500
# 1             Sedan  Sahibinden  2. El  127000  151500
# 2             Sedan  Sahibinden  2. El  175000   19750

# %%
car.info
# Out:
# <bound method DataFrame.info of      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1     16/06/2020   Acura             CL                    -     2015.0
# 2     14/06/2020   Acura             CL                  2.2     1994.0
# 3     11/06/2020   Acura             CL                    -     2013.0
# 4     11/06/2020   Acura             CL                  2.2     2010.0
# ...          ...     ...            ...                  ...        ...
# 9039  06/06/2020   Tofaş          Şahin                  1.6     1994.0
# 9040  05/06/2020   Tofaş          Şahin        Şahin 5 vites     1992.0
# 9041  05/06/2020   Tofaş          Doğan                  SLX     1993.0
# 9042  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1991.0
# 9043  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1996.0
#
# ...

# %%
car["Marka"]
# Out:
# 0       Jaguar
# 1        Acura
# 2        Acura
# 3        Acura
# 4        Acura
#          ...
# 9039     Tofaş
# 9040     Tofaş
# 9041     Tofaş
# 9042     Tofaş
# 9043     Tofaş
# Name: Marka, Length: 9044, dtype: object

# %%
car["Marka"].value_counts()
# Out:
# Renault       2079
# Fiat           654
# Opel           647
# Hyundai        639
# BMW            616
# Mercedes       613
# Ford           602
# Audi           430
# Peugeot        421
# Dacia          323
# Honda          263
# Skoda          259
# Nissan         229
# Citroen        199
# Land Rover     182
# Kia            166
# Seat           151
# Chevrolet      127
# Jeep            91
# Porsche         56
# Tofaş           45
# Acura           42
# Mitsubishi      32
# Mini            31
# Jaguar          30
# Mazda           24
# Volkswagen      18
# Alfa Romeo      17
# Lada            16
# Chrysler        13
# Infiniti        10
# Isuzu            9
# Rover            4
# Maserati         3
# Geely            2
# Chery            1
# Name: Marka, dtype: int64

# %%
car["Arac Tip Grubu"].value_counts()
# Out:
# Clio       490
# Megane     443
# Fluence    426
# Symbol     420
# Focus      359
#           ...
# Omega        1
# Mustang      1
# Cascada      1
# Mokka X      1
# Country      1
# Name: Arac Tip Grubu, Length: 387, dtype: int64

# %%
car["Fiyat"].mean()
# Out:
# 148069.6386554622

# %%
marka=car["Marka"]=="Renault"
model=car["Arac Tip Grubu"]=="Megane"

# %%
car[marka& model]["Fiyat"].mean()
# Out:
# 105790.06320541761

# %%
car[marka& model]
# Out:
#      İlan Tarihi    Marka Arac Tip Grubu          Arac Tip  Model Yıl  \
# 6405  16/06/2020  Renault         Megane         1.6 Alize     1998.0
# 6407  16/06/2020  Renault         Megane  1.6 CC Dynamique     2005.0
# 6419  15/06/2020  Renault         Megane     1.6 Dynamique     2004.0
# 6427  15/06/2020  Renault         Megane             2.0\n     1998.0
# 6450  14/06/2020  Renault         Megane    1.6 Expression     2003.0
# ...          ...      ...            ...               ...        ...
# 8540  18/04/2020  Renault         Megane     1.5 dCi Touch     2017.0
# 8545  18/04/2020  Renault         Megane     1.5 dCi Touch     2017.0
# 8550  18/04/2020  Renault         Megane             Diğer     2009.0
# 8553  18/04/2020  Renault         Megane     1.5 dCi Touch     2017.0
# 8558  18/04/2020  Renault         Megane     1.5 dCi Touch     2017.0
#
#       Yakıt Turu                Vites           CCM     Beygir Gucu  \
# ...

# %%
marka=car["Marka"]=="Mitsubishi"
model=car["Arac Tip Grubu"]=="Lancer"

# %%
car[marka& model]
# Out:
#      İlan Tarihi       Marka Arac Tip Grubu        Arac Tip  Model Yıl  \
# 4960  09/06/2020  Mitsubishi         Lancer  1.6 Invite Otm     2006.0
# 4961  09/06/2020  Mitsubishi         Lancer      1.6 Invite     2013.0
# 4988  03/04/2020  Mitsubishi         Lancer      1.6 Invite     2006.0
#
#       Yakıt Turu           Vites           CCM     Beygir Gucu        Renk  \
# 4960  Benzin/LPG  Otomatik Vites  1301-1600 cc  100 BG ve altı  Gümüş Gri
# 4961  Benzin/LPG       Düz Vites  1301-1600 cc      Bilmiyorum      Beyaz
# 4988  Benzin/LPG       Düz Vites  1301-1600 cc  100 BG ve altı   Lacivert
#
#      Kasa Tipi      Kimden  Durum      Km  Fiyat
# 4960     Sedan  Sahibinden  2. El  135000  55000
# 4961     Sedan   Galeriden  2. El  238000  79750
# 4988     Sedan  Sahibinden  2. El  206000  57500

# %%
car["Marka"].unique()
# Out:
# array(['Jaguar', 'Acura', 'Jeep', 'Hyundai', 'Alfa Romeo', 'Audi',
#        'Mercedes', 'Volkswagen', 'Land Rover', 'BMW', 'Dacia', 'Renault',
#        'Peugeot', 'Chevrolet', 'Chery', 'Citroen', 'Chrysler', 'Fiat',
#        'Ford', 'Honda', 'Geely', 'Infiniti', 'Isuzu', 'Kia', 'Lada',
#        'Maserati', 'Mazda', 'Mini', 'Mitsubishi', 'Nissan', 'Opel',
#        'Porsche', 'Rover', 'Seat', 'Skoda', 'Tofaş'], dtype=object)

# %%
car["İlan Tarihi"].astype("datetime64")
# Out:
# 0      2020-05-27
# 1      2020-06-16
# 2      2020-06-14
# 3      2020-11-06
# 4      2020-11-06
#           ...
# 9039   2020-06-06
# 9040   2020-05-06
# 9041   2020-05-06
# 9042   2020-04-06
# 9043   2020-04-06
# Name: İlan Tarihi, Length: 9044, dtype: datetime64[ns]

# %%
pd.to_datetime(car["İlan Tarihi"])
# Out:
# 0      2020-05-27
# 1      2020-06-16
# 2      2020-06-14
# 3      2020-11-06
# 4      2020-11-06
#           ...
# 9039   2020-06-06
# 9040   2020-05-06
# 9041   2020-05-06
# 9042   2020-04-06
# 9043   2020-04-06
# Name: İlan Tarihi, Length: 9044, dtype: datetime64[ns]

# %%
car["İlan Tarihi"]=pd.to_datetime(car["İlan Tarihi"]) 
car
# Out:
#      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     2020-05-27  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1     2020-06-16   Acura             CL                    -     2015.0
# 2     2020-06-14   Acura             CL                  2.2     1994.0
# 3     2020-11-06   Acura             CL                    -     2013.0
# 4     2020-11-06   Acura             CL                  2.2     2010.0
# ...          ...     ...            ...                  ...        ...
# 9039  2020-06-06   Tofaş          Şahin                  1.6     1994.0
# 9040  2020-05-06   Tofaş          Şahin        Şahin 5 vites     1992.0
# 9041  2020-05-06   Tofaş          Doğan                  SLX     1993.0
# 9042  2020-04-06   Tofaş         Kartal       Kartal 5 Vites     1991.0
# 9043  2020-04-06   Tofaş         Kartal       Kartal 5 Vites     1996.0
#
#       Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# ...

# %%
car["Model Yıl"]=pd.to_numeric(car["Model Yıl"],downcast="integer") 
car
# Out:
#      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     2020-05-27  Jaguar             XF  2.0 D Prestige Plus       2017
# 1     2020-06-16   Acura             CL                    -       2015
# 2     2020-06-14   Acura             CL                  2.2       1994
# 3     2020-11-06   Acura             CL                    -       2013
# 4     2020-11-06   Acura             CL                  2.2       2010
# ...          ...     ...            ...                  ...        ...
# 9039  2020-06-06   Tofaş          Şahin                  1.6       1994
# 9040  2020-05-06   Tofaş          Şahin        Şahin 5 vites       1992
# 9041  2020-05-06   Tofaş          Doğan                  SLX       1993
# 9042  2020-04-06   Tofaş         Kartal       Kartal 5 Vites       1991
# 9043  2020-04-06   Tofaş         Kartal       Kartal 5 Vites       1996
#
#       Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# ...

# %%
car["Model Yıl"].astype("int64")
# Out:
# 0       2017
# 1       2015
# 2       1994
# 3       2013
# 4       2010
#         ...
# 9039    1994
# 9040    1992
# 9041    1993
# 9042    1991
# 9043    1996
# Name: Model Yıl, Length: 9044, dtype: int64

# %%
car.groupby("Marka").mean()
# Out:
#               Model Yıl             Km          Fiyat
# Marka
# Acura       2012.976190  101243.904762  123534.523810
# Alfa Romeo  2010.117647  159852.235294  110961.764706
# Audi        2012.823256  139425.425581  259749.369767
# BMW         2012.082792  140001.512987  294943.738636
# Chery       2010.000000  127000.000000   25500.000000
# Chevrolet   2009.409449  162680.236220   99175.188976
# Chrysler    2003.923077  236846.153846   94126.923077
# Citroen     2012.618090  139889.396985   79485.165829
# Dacia       2015.040248  140804.662539   81834.671827
# Fiat        2011.365443  134623.822630   68076.585627
# Ford        2011.553156  141907.818937   94689.591362
# Geely       2011.500000    7094.000000   43250.000000
# Honda       2008.726236  131830.026616  106489.064639
# Hyundai     2012.020344  133572.968701   98060.931142
# Infiniti    2008.200000  150347.200000  228390.000000
# Isuzu       2014.222222  116288.888889  119788.888889
# ...

# %%
car.groupby(["Marka","Arac Tip Grubu"]).mean()
# Out:
#                              Model Yıl             Km          Fiyat
# Marka      Arac Tip Grubu
# Acura      CL              2009.384615  146065.769231   92688.461538
#            RSX             2019.000000   18835.600000  179103.333333
#            TL              2016.000000  172000.000000   92000.000000
# Alfa Romeo 145             2015.000000  104860.000000  343250.000000
#            147             2006.000000  236625.000000   52562.500000
# ...                                ...            ...            ...
# Tofaş      Doğan           1992.800000  134346.333333   17863.333333
#            Kartal          1994.500000   69522.375000   16212.500000
#            Serçe           1991.500000   99500.000000   14950.000000
#            Şahin           1995.300000   96297.400000   17400.000000
# Volkswagen Polo            2017.000000  142000.000000  123500.000000
#
# [405 rows x 3 columns]

# %%
car.groupby(["Marka","Arac Tip Grubu","Yakıt Turu"]).mean()
# Out:
#                                       Model Yıl             Km          Fiyat
# Marka      Arac Tip Grubu Yakıt Turu
# Acura      CL             Benzin        2016.00   70000.000000   77500.000000
#                           Benzin/LPG    2001.40  171000.000000   39200.000000
#                           Dizel         2011.05  143635.500000  106820.000000
#            RSX            Hibrit        2019.00   18835.600000  179103.333333
#            TL             Dizel         2016.00  172000.000000   92000.000000
# ...                                         ...            ...            ...
# Tofaş      Serçe          Benzin/LPG    1991.50   99500.000000   14950.000000
#            Şahin          Benzin        1992.00   81500.000000   20250.000000
#                           Benzin/LPG    1995.50  102413.777778   17500.000000
#                           Dizel         1995.00    1000.000000   12750.000000
# Volkswagen Polo           Dizel         2017.00  142000.000000  123500.000000
# ...

# %%
car.groupby(["Marka","Arac Tip Grubu","Yakıt Turu"]).first()
# Out:
#                                      İlan Tarihi             Arac Tip  \
# Marka      Arac Tip Grubu Yakıt Turu
# Acura      CL             Benzin      2020-04-14                  2.2
#                           Benzin/LPG  2020-06-14                  2.2
#                           Dizel       2020-06-16                    -
#            RSX            Hibrit      2020-05-29               Type-S
#            TL             Dizel       2020-03-21                Diğer
# ...                                          ...                  ...
# Tofaş      Serçe          Benzin/LPG  2020-06-15                Serçe
#            Şahin          Benzin      2020-06-15        Şahin 5 vites
#                           Benzin/LPG  2020-06-15                    S
#                           Dizel       2020-06-14                  1.6
# Volkswagen Polo           Dizel       2020-06-13  1.4 TDI Comfortline
#
#                                       Model Yıl                Vites  \
# ...
